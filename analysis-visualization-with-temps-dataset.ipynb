# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os

# %%
data = pd.read_csv("Temps.csv", parse_dates=["dt"])
data.head()
# Out:
#           dt  AverageTemperature  ...  Latitude Longitude
# 0 1849-01-01              26.704  ...     5.63N     3.23W
# 1 1849-02-01              27.434  ...     5.63N     3.23W
# 2 1849-03-01              28.101  ...     5.63N     3.23W
# 3 1849-04-01              26.140  ...     5.63N     3.23W
# 4 1849-05-01              25.427  ...     5.63N     3.23W
#
# [5 rows x 7 columns]

# %%
data.dtypes
# Out:
# dt                               datetime64[ns]
# AverageTemperature                      float64
# AverageTemperatureUncertainty           float64
# City                                     object
# Country                                  object
# Latitude                                 object
# Longitude                                object
# dtype: object

# %%
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 239177 entries, 0 to 239176
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   dt                             239177 non-null  datetime64[ns]
#  1   AverageTemperature             228175 non-null  float64
#  2   AverageTemperatureUncertainty  228175 non-null  float64
#  3   City                           239177 non-null  object
#  4   Country                        239177 non-null  object
#  5   Latitude                       239177 non-null  object
#  6   Longitude                      239177 non-null  object
# dtypes: datetime64[ns](1), float64(2), object(4)
# memory usage: 12.8+ MB
#        AverageTemperature  AverageTemperatureUncertainty
# count       228175.000000                  228175.000000
# mean            18.125969                       0.969343
# std             10.024800                       0.979644
# ...

# %%
data.shape
# Out:
# (239177, 7)

# %%
print(data_son.shape)
data_son.isnull().sum()/data.shape[0] *100
# Out:
# (228175, 7)
# dt                               0.0
# AverageTemperature               0.0
# AverageTemperatureUncertainty    0.0
# City                             0.0
# Country                          0.0
# Latitude                         0.0
# Longitude                        0.0
# dtype: float64

# %%
data_son[["Country"]].value_counts().iloc[0:6].plot()
data_son[["Country"]].value_counts().count()
# Out:
# 49

# %%
data_son[(data_son["Country"] == "Turkey") & (data_son["AverageTemperature"] > 29)]
# Out:
#               dt  AverageTemperature  ...  Latitude Longitude
# 93548 1757-07-01              29.121  ...    37.78N    26.44E
# 93596 1761-07-01              29.845  ...    37.78N    26.44E
#
# [2 rows x 7 columns]

# %%
data_selected = data_son[(data_son["Country"].isin(["Turkey","China","United States"]))]

# %%
data_selected
# Out:
#                dt  AverageTemperature  ...  Latitude Longitude
# 11893  1755-01-01              -3.657  ...    39.38N    33.29E
# 11894  1755-02-01              -2.453  ...    39.38N    33.29E
# 11895  1755-03-01               4.458  ...    39.38N    33.29E
# 11898  1755-06-01              21.018  ...    39.38N    33.29E
# 11899  1755-07-01              22.099  ...    39.38N    33.29E
# ...           ...                 ...  ...       ...       ...
# 239171 2013-04-01              12.563  ...    34.56N   108.97E
# 239172 2013-05-01              18.979  ...    34.56N   108.97E
# 239173 2013-06-01              23.522  ...    34.56N   108.97E
# 239174 2013-07-01              25.251  ...    34.56N   108.97E
# 239175 2013-08-01              24.528  ...    34.56N   108.97E
#
# [52428 rows x 7 columns]

# %%
data_selected.groupby(["Country"]).mean()
# Out:
#                AverageTemperature  AverageTemperatureUncertainty
# Country
# China                   11.793666                       0.890271
# Turkey                  13.790998                       1.391654
# United States           11.257246                       1.200292

# %%
data_selected.groupby(["Country"]).agg(["min","max","mean"])
# Out:
#               AverageTemperature          ... AverageTemperatureUncertainty
#                              min     max  ...                           max      mean
# Country                                   ...
# China                    -26.772  31.233  ...                         6.870  0.890271
# Turkey                    -6.280  29.845  ...                         8.459  1.391654
# United States             -9.162  29.141  ...                        10.193  1.200292
#
# [3 rows x 6 columns]

# %%
data_selected.head()
# Out:
#               dt  AverageTemperature  ...  Latitude Longitude
# 11893 1755-01-01              -3.657  ...    39.38N    33.29E
# 11894 1755-02-01              -2.453  ...    39.38N    33.29E
# 11895 1755-03-01               4.458  ...    39.38N    33.29E
# 11898 1755-06-01              21.018  ...    39.38N    33.29E
# 11899 1755-07-01              22.099  ...    39.38N    33.29E
#
# [5 rows x 7 columns]

# %%
tr_avg_temps = data_selected[data_selected["Country"] == "Turkey"]["AverageTemperature"]
br_avg_temps = data_selected[data_selected["Country"] == "China"]["AverageTemperature"]

# %%
sns.distplot(tr_avg_temps)
sns.distplot(br_avg_temps);
selected
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
ulkeler = data_selected["Country"].unique()

# %%
plt.figure(figsize=(10,10))
for i in ulkeler:
  sns.displot(data_selected[data_selected["Country"] == i ]["AverageTemperature"]);
plt.legend(ulkeler)

# %%
tr_Data = data_selected[(data_selected["Country"]=="Turkey") & (data_selected["dt"]> "01.01.1990")]

# %%
plt.figure(figsize=(15,5))
sns.scatterplot(x="dt",y= "AverageTemperature", data=tr_Data)
